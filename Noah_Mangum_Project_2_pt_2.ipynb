# %% [markdown]
# <a href="https://colab.research.google.com/github/noahmangum52/football-stats/blob/main/Noah_Mangum_Project_2_pt_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
path='https://raw.githubusercontent.com/noahmangum52/football-stats/main/College-Football-Original-Dataset%20-%20Raw_Data%20(1).csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#   UniversityName  Year        TeamID  CMP  ATT     YDS  CMPPercent   YPA  LNG  \
# 0       AirForce  2010  AirForce2010   88  168  1551.0        52.4   9.2   63
# 1       AirForce  2011  AirForce2011  123  204  1821.0        60.3   8.9   55
# 2       AirForce  2012  AirForce2012   83  151  1334.0        55.0   8.8   58
# 3       AirForce  2013  AirForce2013   93  174  1259.0        53.4   7.2   71
# 4       AirForce  2014  AirForce2014  117  206  1893.0        56.8   9.2   74
# 5       AirForce  2015  AirForce2015   87  170  1847.0        51.2  10.9   75
# 6       AirForce  2016  AirForce2016   68  150  1752.0        45.3  11.7   75
# 7       AirForce  2017  AirForce2017   69  142  1321.0        48.6   9.3   64
# 8       AirForce  2018  AirForce2018   93  168  1576.0        55.4   9.4   69
# 9       AirForce  2019  AirForce2019   68  126  1602.0        54.0  12.7   81
#
#    TD  INT  SACK  SYL    RTG  R_ATT  R_AVG  TOTAL_PLAYS RUN_PERCENT  \
# ...

# %%
df.describe()
# Out:
#               Year          CMP          ATT          YDS   CMPPercent  \
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean   2015.084548   233.807580   391.147959  2866.031341    59.164140
# std       3.146113    70.806798   101.276791   866.256747     5.652128
# min    2010.000000    20.000000    54.000000   361.000000    30.800000
# 25%    2012.000000   192.000000   339.750000  2307.750000    55.600000
# 50%    2015.000000   238.000000   401.000000  2854.500000    59.400000
# 75%    2018.000000   275.000000   453.250000  3386.000000    62.900000
# max    2020.000000   510.000000   771.000000  6301.000000    76.200000
#
#                YPA          LNG           TD          INT         SACK  \
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      7.290306    72.416181    20.783528    10.870991    25.167638
# std       1.138249    12.191499     9.014564     4.186582     9.403487
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print(df.dtypes)
# Out:
# UniversityName     object
# Year                int64
# TeamID             object
# CMP                 int64
# ATT                 int64
# YDS               float64
# CMPPercent        float64
# YPA               float64
# LNG                 int64
# TD                  int64
# INT                 int64
# SACK                int64
# SYL                 int64
# RTG               float64
# R_ATT               int64
# R_AVG             float64
# TOTAL_PLAYS         int64
# RUN_PERCENT        object
# PASS_PERCENT       object
# dtype: object

# %%
df.corr()
# Out:
#                  Year       CMP       ATT       YDS  CMPPercent       YPA  \
# Year         1.000000 -0.169449 -0.203693 -0.136094    0.013682  0.011106
# CMP         -0.169449  1.000000  0.960126  0.926422    0.635637  0.181670
# ATT         -0.203693  0.960126  1.000000  0.873171    0.417173  0.022581
# YDS         -0.136094  0.926422  0.873171  1.000000    0.628697  0.475638
# CMPPercent   0.013682  0.635637  0.417173  0.628697    1.000000  0.501534
# YPA          0.011106  0.181670  0.022581  0.475638    0.501534  1.000000
# LNG         -0.021361  0.261234  0.247824  0.374018    0.191665  0.358419
# TD          -0.081293  0.733652  0.646911  0.858022    0.600150  0.570476
# INT         -0.251192  0.327944  0.455741  0.233952   -0.145387 -0.275651
# SACK        -0.034947  0.207447  0.272502  0.150510   -0.026377 -0.168999
# SYL          0.076857 -0.248917 -0.315119 -0.184711    0.012057  0.172650
# RTG          0.034045  0.366997  0.171152  0.582505    0.734193  0.906304
# ...

# %%
df[['ATT', 'YDS', 'TD', 'CMP','CMPPercent','YPA','RTG']].corr()
# Out:
#                  ATT       YDS        TD       CMP  CMPPercent       YPA  \
# ATT         1.000000  0.873171  0.646911  0.960126    0.417173  0.022581
# YDS         0.873171  1.000000  0.858022  0.926422    0.628697  0.475638
# TD          0.646911  0.858022  1.000000  0.733652    0.600150  0.570476
# CMP         0.960126  0.926422  0.733652  1.000000    0.635637  0.181670
# CMPPercent  0.417173  0.628697  0.600150  0.635637    1.000000  0.501534
# YPA         0.022581  0.475638  0.570476  0.181670    0.501534  1.000000
# RTG         0.171152  0.582505  0.730055  0.366997    0.734193  0.906304
#
#                  RTG
# ATT         0.171152
# YDS         0.582505
# TD          0.730055
# CMP         0.366997
# CMPPercent  0.734193
# YPA         0.906304
# RTG         1.000000

# %%
sns.regplot(x="CMPPercent", y="YDS", data=df)
plt.ylim(0,)
# Out:
# (0.0, 6618.187606465877)

# %%
sns.regplot(x="CMP", y="YDS", data=df)
plt.ylim(0,)
# Out:
# (0.0, 6598.0)

# %%
feature_cols = ['ATT', 'YDS', 'TD','CMPPercent','YPA','RTG']
X = df[feature_cols]
y = df['CMP']

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train, y_train)
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# -177.256838149859
# [ 0.48531024  0.01025392  0.65018452  4.03944797  3.7499992  -0.66531638]

# %%
y_pred = linreg.predict(X_test)

# %%
dt = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
dt
# Out:
#       Actual   Predicted
# 608      299  296.621559
# 314      234  235.326715
# 668      263  264.758577
# 272      319  312.181677
# 714      297  299.372678
# ...      ...         ...
# 1366     183  185.763463
# 165      235  237.845574
# 169      230  237.382738
# 816      290  290.409585
# 1117     248  255.219491
#
# [343 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.455522551247726
# Mean Squared Error: 62.227030478017745
# Root Mean Squared Error: 7.88841115041665

# %%
sns.boxplot(x="Year", y="YDS", data=df)

# %%
sns.boxplot(x="UniversityName", y="RTG", data=df)

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['CMP'], df['YDS'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9264216758151068  with a P-value of P =  0.0
